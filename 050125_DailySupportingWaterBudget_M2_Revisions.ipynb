# %%
import pandas as pd
import seaborn as sns
import numpy as np
from scipy import stats
#sns.set_theme(style="white", palette=None)
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager

# %%
sns.set_theme(style="white")

# %%
datetime_series = pd.date_range('1998-01-01', periods=6574, freq='D')
datetime_series
# Out:
# DatetimeIndex(['1998-01-01', '1998-01-02', '1998-01-03', '1998-01-04',
#                '1998-01-05', '1998-01-06', '1998-01-07', '1998-01-08',
#                '1998-01-09', '1998-01-10',
#                ...
#                '2015-12-22', '2015-12-23', '2015-12-24', '2015-12-25',
#                '2015-12-26', '2015-12-27', '2015-12-28', '2015-12-29',
#                '2015-12-30', '2015-12-31'],
#               dtype='datetime64[ns]', length=6574, freq='D')

# %%
A1 = 'MULTI_HaymanFire_1998Lndscp_CC2002_LANDISCF_Harvest_29AUG23h/Results_659322/DailyResults.csv'

df_A1 =pd.read_csv(A1, dtype=None)
df_A1
df_A1.keys()
df_A1.index = datetime_series[:].rename('Date')
df_A1
df_qmod_A1 =df_A1[['Step','Year', 'PET(mm/day)_Delineated_Average', 'ET(mm/day)_Delineated_Average', 'Runoff_All(mm/day)_Delineated_Average', 'Rain(mm/day)_Delineated_Average']]
print(df_qmod_A1.head())
#df =pd.DataFrame(runs, index=runs.index, columns=runs.columns)
df_qmod_A1.columns =df_qmod_A1.keys()
print(df_qmod_A1.keys())
df_qmod_A1['Run'] ='A1'
# Out:
#             Step  Year  PET(mm/day)_Delineated_Average  \
# Date
# 1998-01-01     0  1998                        3.673928
# 1998-01-02     1  1998                        3.795632
# 1998-01-03     2  1998                        3.753382
# 1998-01-04     3  1998                        3.148573
# 1998-01-05     4  1998                        2.804254
#
#             ET(mm/day)_Delineated_Average  \
# Date
# 1998-01-01                       2.656185
# 1998-01-02                       2.740002
# 1998-01-03                       2.694706
# 1998-01-04                       2.250851
# 1998-01-05                       1.997586
#
#             Runoff_All(mm/day)_Delineated_Average  \
# Date
# 1998-01-01                               5.327482
# 1998-01-02                               2.624240
# 1998-01-03                               2.015208
# 1998-01-04                               1.613030
# 1998-01-05                               1.340557
#
#             Rain(mm/day)_Delineated_Average
# ...

# %%
df_qmod_A1.head()
# Out:
#             Step  Year  PET(mm/day)_Delineated_Average  \
# Date
# 1998-01-01     0  1998                        3.673928
# 1998-01-02     1  1998                        3.795632
# 1998-01-03     2  1998                        3.753382
# 1998-01-04     3  1998                        3.148573
# 1998-01-05     4  1998                        2.804254
#
#             ET(mm/day)_Delineated_Average  \
# Date
# 1998-01-01                       2.656185
# 1998-01-02                       2.740002
# 1998-01-03                       2.694706
# 1998-01-04                       2.250851
# 1998-01-05                       1.997586
#
#             Runoff_All(mm/day)_Delineated_Average  \
# Date
# 1998-01-01                               5.327482
# 1998-01-02                               2.624240
# 1998-01-03                               2.015208
# 1998-01-04                               1.613030
# 1998-01-05                               1.340557
#
# ...

# %%
datetime_series_9219 = pd.date_range('1992-01-01', periods=10227, freq='D')
datetime_series_9219
# Out:
# DatetimeIndex(['1992-01-01', '1992-01-02', '1992-01-03', '1992-01-04',
#                '1992-01-05', '1992-01-06', '1992-01-07', '1992-01-08',
#                '1992-01-09', '1992-01-10',
#                ...
#                '2019-12-22', '2019-12-23', '2019-12-24', '2019-12-25',
#                '2019-12-26', '2019-12-27', '2019-12-28', '2019-12-29',
#                '2019-12-30', '2019-12-31'],
#               dtype='datetime64[ns]', length=10227, freq='D')

# %%
A1_nldas = 'C:/Users/KVENABLE/OneDrive - Environmental Protection Agency (EPA)/022723_OldLaptopFiles/2023-05-12_nldas_SR_mm_Index_659322_1992_2019.csv'
df_nldas_A1 =pd.read_csv(A1_nldas, dtype=None, skiprows=0, header=None)
df_nldas_A1 = df_nldas_A1.rename(columns={0:'Runoff_All(mm/day)_Delineated_Average'}) 
df_nldas_A1.info()
#datetime_series_9208 = pd.date_range('1992-01-01', periods=6210, freq='D')
#datetime_series_9208
df_nldas_A1.index = datetime_series_9219[:].rename('Date')
df_nldas_A1.head()
df_nldas_A1['Run'] ='NLDAS_659322'
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10227 entries, 0 to 10226
# Data columns (total 1 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Runoff_All(mm/day)_Delineated_Average  10227 non-null  float64
# dtypes: float64(1)
# memory usage: 80.0 KB

# %%
datetime_series_9806 = pd.date_range('1998-01-01', periods=3287, freq='D')
datetime_series_9806
# Out:
# DatetimeIndex(['1998-01-01', '1998-01-02', '1998-01-03', '1998-01-04',
#                '1998-01-05', '1998-01-06', '1998-01-07', '1998-01-08',
#                '1998-01-09', '1998-01-10',
#                ...
#                '2006-12-22', '2006-12-23', '2006-12-24', '2006-12-25',
#                '2006-12-26', '2006-12-27', '2006-12-28', '2006-12-29',
#                '2006-12-30', '2006-12-31'],
#               dtype='datetime64[ns]', length=3287, freq='D')

# %%
df_nldas_A1[datetime_series_9806[0]:datetime_series_9806[-1]].describe()
# Out:
#        Runoff_All(mm/day)_Delineated_Average
# count                            3287.000000
# mean                                0.151482
# std                                 0.705371
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.030000
# max                                19.630000

# %%
A2 = 'MULTI_HaymanFire_1998Lndscp_CC2002_LANDISCF_Harvest_02SEP23a/Results_420929/DailyResults.csv'

df_A2 =pd.read_csv(A2, dtype=None)
df_A2
df_A2.keys()
df_A2.index = datetime_series[:].rename('Date')
df_A2
df_qmod_A2 =df_A2[['Step','Year', 'PET(mm/day)_Delineated_Average', 'ET(mm/day)_Delineated_Average', 'Runoff_All(mm/day)_Delineated_Average', 'Rain(mm/day)_Delineated_Average']]
print(df_qmod_A2.head())
#df =pd.DataFrame(runs, index=runs.index, columns=runs.columns)
df_qmod_A2.columns =df_qmod_A2.keys()
print(df_qmod_A2.keys())
df_qmod_A2['Run'] ='A2'
# Out:
#             Step  Year  PET(mm/day)_Delineated_Average  \
# Date
# 1998-01-01     0  1998                        3.693975
# 1998-01-02     1  1998                        3.818933
# 1998-01-03     2  1998                        3.775853
# 1998-01-04     3  1998                        3.161935
# 1998-01-05     4  1998                        2.821655
#
#             ET(mm/day)_Delineated_Average  \
# Date
# 1998-01-01                       2.662388
# 1998-01-02                       2.747165
# 1998-01-03                       2.704659
# 1998-01-04                       2.256904
# 1998-01-05                       2.008081
#
#             Runoff_All(mm/day)_Delineated_Average  \
# Date
# 1998-01-01                               3.739154
# 1998-01-02                               1.650207
# 1998-01-03                               1.240118
# 1998-01-04                               0.986098
# 1998-01-05                               0.813509
#
#             Rain(mm/day)_Delineated_Average
# ...

# %%
df_qmod_A2.head()
# Out:
#             Step  Year  PET(mm/day)_Delineated_Average  \
# Date
# 1998-01-01     0  1998                        3.693975
# 1998-01-02     1  1998                        3.818933
# 1998-01-03     2  1998                        3.775853
# 1998-01-04     3  1998                        3.161935
# 1998-01-05     4  1998                        2.821655
#
#             ET(mm/day)_Delineated_Average  \
# Date
# 1998-01-01                       2.662388
# 1998-01-02                       2.747165
# 1998-01-03                       2.704659
# 1998-01-04                       2.256904
# 1998-01-05                       2.008081
#
#             Runoff_All(mm/day)_Delineated_Average  \
# Date
# 1998-01-01                               3.739154
# 1998-01-02                               1.650207
# 1998-01-03                               1.240118
# 1998-01-04                               0.986098
# 1998-01-05                               0.813509
#
# ...

# %%
A2_nldas = 'C:/Users/KVENABLE/OneDrive - Environmental Protection Agency (EPA)/022723_OldLaptopFiles/022025_HMSGEE/2023-05-11_nldas_SR_mm_Index_420929_1992_2019.csv'
df_nldas_A2 =pd.read_csv(A2_nldas, dtype=None, skiprows=0, header=None)
df_nldas_A2 = df_nldas_A2.rename(columns={0:'Runoff_All(mm/day)_Delineated_Average'}) 
df_nldas_A2.info()
#datetime_series_9208 = pd.date_range('1992-01-01', periods=6210, freq='D')
#datetime_series_9208
df_nldas_A2.index = datetime_series_9219[:].rename('Date')
df_nldas_A2.head()
df_nldas_A2['Run'] ='NLDAS_420929'
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10227 entries, 0 to 10226
# Data columns (total 1 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Runoff_All(mm/day)_Delineated_Average  10227 non-null  float64
# dtypes: float64(1)
# memory usage: 80.0 KB

# %%
df_nldas_A2[datetime_series_9806[0]:datetime_series_9806[-1]].describe()
# Out:
#        Runoff_All(mm/day)_Delineated_Average
# count                            3287.000000
# mean                                0.151482
# std                                 0.705371
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.030000
# max                                19.630000

# %%
df_nldas_A2.keys()
# Out:
# Index(['Runoff_All(mm/day)_Delineated_Average', 'Run'], dtype='object')

# %%
A3 = 'MULTI_HaymanFire_1998Lndscp_CC2002_LANDISCF_Harvest_02SEP23a/Results_421671/DailyResults.csv'

df_A3 =pd.read_csv(A3, dtype=None)
df_A3
df_A3.keys()
df_A3.index = datetime_series[:].rename('Date')
df_A3
df_qmod_A3 =df_A3[['Step','Year', 'PET(mm/day)_Delineated_Average', 'ET(mm/day)_Delineated_Average', 'Runoff_All(mm/day)_Delineated_Average', 'Rain(mm/day)_Delineated_Average']]
print(df_qmod_A3.head())
#df =pd.DataFrame(runs, index=runs.index, columns=runs.columns)
df_qmod_A3.columns =df_qmod_A3.keys()
print(df_qmod_A3.keys())
df_qmod_A3['Run'] ='A3'
# Out:
#             Step  Year  PET(mm/day)_Delineated_Average  \
# Date
# 1998-01-01     0  1998                        3.693966
# 1998-01-02     1  1998                        3.818921
# 1998-01-03     2  1998                        3.775840
# 1998-01-04     3  1998                        3.161925
# 1998-01-05     4  1998                        2.821644
#
#             ET(mm/day)_Delineated_Average  \
# Date
# 1998-01-01                       2.662380
# 1998-01-02                       2.747155
# 1998-01-03                       2.704648
# 1998-01-04                       2.256896
# 1998-01-05                       2.008072
#
#             Runoff_All(mm/day)_Delineated_Average  \
# Date
# 1998-01-01                               3.739298
# 1998-01-02                               1.650214
# 1998-01-03                               1.240090
# 1998-01-04                               0.986058
# 1998-01-05                               0.813468
#
#             Rain(mm/day)_Delineated_Average
# ...

# %%
df_qmod_A3.head()
# Out:
#             Step  Year  PET(mm/day)_Delineated_Average  \
# Date
# 1998-01-01     0  1998                        3.693966
# 1998-01-02     1  1998                        3.818921
# 1998-01-03     2  1998                        3.775840
# 1998-01-04     3  1998                        3.161925
# 1998-01-05     4  1998                        2.821644
#
#             ET(mm/day)_Delineated_Average  \
# Date
# 1998-01-01                       2.662380
# 1998-01-02                       2.747155
# 1998-01-03                       2.704648
# 1998-01-04                       2.256896
# 1998-01-05                       2.008072
#
#             Runoff_All(mm/day)_Delineated_Average  \
# Date
# 1998-01-01                               3.739298
# 1998-01-02                               1.650214
# 1998-01-03                               1.240090
# 1998-01-04                               0.986058
# 1998-01-05                               0.813468
#
# ...

# %%
df_qmod_A3['Runoff_All(mm/day)_Delineated_Average'][datetime_series_9806[0]:datetime_series_9806[-1]].describe()
# Out:
# count    3287.000000
# mean        0.050080
# std         0.614377
# min         0.000008
# 25%         0.000147
# 50%         0.001305
# 75%         0.013741
# max        28.964772
# Name: Runoff_All(mm/day)_Delineated_Average, dtype: float64

# %%
A3_nldas = 'C:/Users/KVENABLE/OneDrive - Environmental Protection Agency (EPA)/022723_OldLaptopFiles/2023-05-11_nldas_SR_mm_Index_421671_1992_2008.csv'
df_nldas_A3 =pd.read_csv(A3_nldas, dtype=None, skiprows=0, header=None)
df_nldas_A3 = df_nldas_A3.rename(columns={0:'Runoff_All(mm/day)_Delineated_Average'}) 
df_nldas_A3.info()
datetime_series_9208 = pd.date_range('1992-01-01', periods=6210, freq='D')
#datetime_series_9208
df_nldas_A3.index = datetime_series_9208[:].rename('Date')
df_nldas_A3.head()
df_nldas_A3['Run'] ='NLDAS_421671'
df_nldas_A3.keys()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6210 entries, 0 to 6209
# Data columns (total 1 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Runoff_All(mm/day)_Delineated_Average  6210 non-null   float64
# dtypes: float64(1)
# memory usage: 48.6 KB
# Index(['Runoff_All(mm/day)_Delineated_Average', 'Run'], dtype='object')

# %%
df_nldas_A3[datetime_series_9806[0]:datetime_series_9806[-1]].describe()
# Out:
#        Runoff_All(mm/day)_Delineated_Average
# count                            3287.000000
# mean                                0.151482
# std                                 0.705371
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.030000
# max                                19.630000

# %%
A4 = 'MULTI_HaymanFire_1998Lndscp_CC2002_LANDISCF_Harvest_02SEP23a/Results_451289/DailyResults.csv'

df_A4 =pd.read_csv(A4, dtype=None)
df_A4
df_A4.keys()
df_A4.index = datetime_series[:].rename('Date')
df_A4
df_qmod_A4 =df_A4[['Step','Year', 'PET(mm/day)_Delineated_Average', 'ET(mm/day)_Delineated_Average', 'Runoff_All(mm/day)_Delineated_Average', 'Rain(mm/day)_Delineated_Average']]
print(df_qmod_A4.head())
#df =pd.DataFrame(runs, index=runs.index, columns=runs.columns)
df_qmod_A4.columns =df_qmod_A4.keys()
print(df_qmod_A4.keys())
df_qmod_A4['Run'] ='A4'
# Out:
#             Step  Year  PET(mm/day)_Delineated_Average  \
# Date
# 1998-01-01     0  1998                        3.684804
# 1998-01-02     1  1998                        3.808216
# 1998-01-03     2  1998                        3.764684
# 1998-01-04     3  1998                        3.153350
# 1998-01-05     4  1998                        2.811816
#
#             ET(mm/day)_Delineated_Average  \
# Date
# 1998-01-01                       2.654768
# 1998-01-02                       2.738352
# 1998-01-03                       2.696061
# 1998-01-04                       2.250544
# 1998-01-05                       2.001061
#
#             Runoff_All(mm/day)_Delineated_Average  \
# Date
# 1998-01-01                               3.515798
# 1998-01-02                               1.496638
# 1998-01-03                               1.118814
# 1998-01-04                               0.888964
# 1998-01-05                               0.733228
#
#             Rain(mm/day)_Delineated_Average
# ...

# %%
df_qmod_A4.head()
# Out:
#             Step  Year  PET(mm/day)_Delineated_Average  \
# Date
# 1998-01-01     0  1998                        3.684804
# 1998-01-02     1  1998                        3.808216
# 1998-01-03     2  1998                        3.764684
# 1998-01-04     3  1998                        3.153350
# 1998-01-05     4  1998                        2.811816
#
#             ET(mm/day)_Delineated_Average  \
# Date
# 1998-01-01                       2.654768
# 1998-01-02                       2.738352
# 1998-01-03                       2.696061
# 1998-01-04                       2.250544
# 1998-01-05                       2.001061
#
#             Runoff_All(mm/day)_Delineated_Average  \
# Date
# 1998-01-01                               3.515798
# 1998-01-02                               1.496638
# 1998-01-03                               1.118814
# 1998-01-04                               0.888964
# 1998-01-05                               0.733228
#
# ...

# %%
df_qmod_A4['Runoff_All(mm/day)_Delineated_Average'][datetime_series_9806[0]:datetime_series_9806[-1]].describe()
# Out:
# count    3287.000000
# mean        0.047758
# std         0.604456
# min         0.000007
# 25%         0.000130
# 50%         0.001189
# 75%         0.012684
# max        28.788523
# Name: Runoff_All(mm/day)_Delineated_Average, dtype: float64

# %%
A4_nldas = 'C:/Users/KVENABLE/OneDrive - Environmental Protection Agency (EPA)/022723_OldLaptopFiles/2023-06-28_nldas_SR_mm_Index_451289_1992_2019.csv'
df_nldas_A4 =pd.read_csv(A4_nldas, dtype=None, skiprows=0, header=None)
df_nldas_A4 = df_nldas_A4.rename(columns={0:'Runoff_All(mm/day)_Delineated_Average'}) 
df_nldas_A4.index = datetime_series_9219[:].rename('Date')
df_nldas_A4.head()
df_nldas_A4['Run'] ='NLDAS_451289'

# %%
df_nldas_A4[datetime_series_9806[0]:datetime_series_9806[-1]].describe()
# Out:
#        Runoff_All(mm/day)_Delineated_Average
# count                            3287.000000
# mean                                0.151482
# std                                 0.705371
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.030000
# max                                19.630000

# %%
A5_nldas = 'C:/Users/KVENABLE/OneDrive - Environmental Protection Agency (EPA)/022723_OldLaptopFiles/2023-08-28_nldas_SR_mm_Index_39377_1992_2019.csv'
df_nldas_A5 =pd.read_csv(A5_nldas, dtype=None, skiprows=0, header=None)
df_nldas_A5 = df_nldas_A5.rename(columns={0:'Runoff_All(mm/day)_Delineated_Average'}) 
df_nldas_A5.index = datetime_series_9219[:].rename('Date')
df_nldas_A5.head()
df_nldas_A5['Run'] ='NLDAS_39377'

# %%
df_nldas_A5[datetime_series_9806[0]:datetime_series_9806[-1]].describe()
# Out:
#        Runoff_All(mm/day)_Delineated_Average
# count                            3287.000000
# mean                                0.172869
# std                                 0.938984
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.040000
# max                                37.030000

# %%
df_nldas_f['Runoff_All(mm/day)_Delineated_Average'].describe()
# Out:
# count    3287.000000
# mean        0.174247
# std         0.939102
# min         0.000000
# 25%         0.000000
# 50%         0.001000
# 75%         0.042000
# max        37.040000
# Name: Runoff_All(mm/day)_Delineated_Average, dtype: float64

# %%
A5 = 'C:/Users/KVENABLE/OneDrive - Environmental Protection Agency (EPA)/OldLaptopFiles/VELMA_HAYMAN/Output/MULTI_Brush_Creek_1998Lndscp_CC2002_LANDISCF_Harvest_25SEP23a/Results_293321/DailyResults.csv'
#replacing filename for 293321 results since we are foucsing on LANDISCF simmulations  04/23/25
#A5 = 'C:/Users/KVENABLE/OneDrive - Environmental Protection Agency (EPA)/OldLaptopFiles/VELMA_HAYMAN/Output/MULTI_Brush_Creek_1998Lndscp_CC2002_LANDISC_Harvest_27DEC24A/Results_293321/DailyResults.csv'

df_A5 =pd.read_csv(A5, dtype=None)
df_A5
df_A5.keys()
df_A5.index = datetime_series[:].rename('Date')
df_A5
df_qmod_A5 =df_A5[['Step','Year', 'PET(mm/day)_Delineated_Average', 'ET(mm/day)_Delineated_Average', 'Runoff_All(mm/day)_Delineated_Average', 'Rain(mm/day)_Delineated_Average']]
print(df_qmod_A5.head())
#df =pd.DataFrame(runs, index=runs.index, columns=runs.columns)
df_qmod_A5.columns =df_qmod_A5.keys()
print(df_qmod_A5.keys())
df_qmod_A5['Run'] ='A5'
# Out:
#             Step  Year  PET(mm/day)_Delineated_Average  \
# Date
# 1998-01-01     0  1998                        3.626759
# 1998-01-02     1  1998                        3.740444
# 1998-01-03     2  1998                        3.691104
# 1998-01-04     3  1998                        3.090934
# 1998-01-05     4  1998                        2.742942
#
#             ET(mm/day)_Delineated_Average  \
# Date
# 1998-01-01                       2.622951
# 1998-01-02                       2.701823
# 1998-01-03                       2.650948
# 1998-01-04                       2.210073
# 1998-01-05                       1.954144
#
#             Runoff_All(mm/day)_Delineated_Average  \
# Date
# 1998-01-01                               5.152964
# 1998-01-02                               2.891891
# 1998-01-03                               2.301611
# 1998-01-04                               1.879426
# 1998-01-05                               1.576816
#
#             Rain(mm/day)_Delineated_Average
# ...

# %%
df_qmod_A5.head()
# Out:
#             Step  Year  PET(mm/day)_Delineated_Average  \
# Date
# 1998-01-01     0  1998                        3.626759
# 1998-01-02     1  1998                        3.740444
# 1998-01-03     2  1998                        3.691104
# 1998-01-04     3  1998                        3.090934
# 1998-01-05     4  1998                        2.742942
#
#             ET(mm/day)_Delineated_Average  \
# Date
# 1998-01-01                       2.622951
# 1998-01-02                       2.701823
# 1998-01-03                       2.650948
# 1998-01-04                       2.210073
# 1998-01-05                       1.954144
#
#             Runoff_All(mm/day)_Delineated_Average  \
# Date
# 1998-01-01                               5.152964
# 1998-01-02                               2.891891
# 1998-01-03                               2.301611
# 1998-01-04                               1.879426
# 1998-01-05                               1.576816
#
# ...

# %%
df_nldas_f= pd.read_csv('C:/Users/KVENABLE/OneDrive - Environmental Protection Agency (EPA)/VELMA/Sucessful Hayman Runs Backup/032123_VELMA_Output_WB/VELMA_Ouput_Results/033123_NLDAS_ALL_VELMAcompare_9806.csv')
df_nldas_f.index = pd.to_datetime(df_nldas_f['Unnamed: 0']).rename('Date')
#df_nldas_f = df_nldas_f.drop(['Unnamed: 0'])
df_nldas_f = df_nldas_f.loc[:,['Total_Rain', 'Total_Observed_Runoff(mm)', 'Run','Total_Simulated_Runoff(mm)', 'Total_AET(mm)']]
df_nldas_f = df_nldas_f.rename(columns={'Total_Simulated_Runoff(mm)':'Runoff_All(mm/day)_Delineated_Average', 'Total_Rain':'Rain(mm/day)_Delineated_Average','Total_AET(mm)':'ET(mm/day)_Delineated_Average'})
#renaming values from NLDAS to NLDAS and outlet number 
df_nldas_f.Run = 'NLDAS_293321'
df_nldas_f.head()
# Out:
#             Rain(mm/day)_Delineated_Average  Total_Observed_Runoff(mm)  \
# Date
# 1998-01-01                             0.33                      0.458
# 1998-01-02                             0.00                      0.410
# 1998-01-03                             0.00                      0.423
# 1998-01-04                             0.00                      0.195
# 1998-01-05                             3.35                      0.123
#
#                      Run  Runoff_All(mm/day)_Delineated_Average  \
# Date
# 1998-01-01  NLDAS_293321                                  0.458
# 1998-01-02  NLDAS_293321                                  0.410
# 1998-01-03  NLDAS_293321                                  0.423
# 1998-01-04  NLDAS_293321                                  0.195
# 1998-01-05  NLDAS_293321                                  0.123
#
#             ET(mm/day)_Delineated_Average
# Date
# 1998-01-01                           0.02
# 1998-01-02                          -0.01
# ...

# %%
df_nldas_f.head()
# Out:
#             Rain(mm/day)_Delineated_Average  Total_Observed_Runoff(mm)    Run  \
# Date
# 1998-01-01                             0.33                      0.458  NLDAS
# 1998-01-02                             0.00                      0.410  NLDAS
# 1998-01-03                             0.00                      0.423  NLDAS
# 1998-01-04                             0.00                      0.195  NLDAS
# 1998-01-05                             3.35                      0.123  NLDAS
#
#             Runoff_All(mm/day)_Delineated_Average  \
# Date
# 1998-01-01                                  0.458
# 1998-01-02                                  0.410
# 1998-01-03                                  0.423
# 1998-01-04                                  0.195
# 1998-01-05                                  0.123
#
#             ET(mm/day)_Delineated_Average
# Date
# 1998-01-01                           0.02
# 1998-01-02                          -0.01
# 1998-01-03                          -0.02
# ...

# %%
datetime_series_9806 = pd.date_range('1998-01-01', periods=3287, freq='D')
datetime_series_9806
# Out:
# DatetimeIndex(['1998-01-01', '1998-01-02', '1998-01-03', '1998-01-04',
#                '1998-01-05', '1998-01-06', '1998-01-07', '1998-01-08',
#                '1998-01-09', '1998-01-10',
#                ...
#                '2006-12-22', '2006-12-23', '2006-12-24', '2006-12-25',
#                '2006-12-26', '2006-12-27', '2006-12-28', '2006-12-29',
#                '2006-12-30', '2006-12-31'],
#               dtype='datetime64[ns]', length=3287, freq='D')

# %%
datetime_series_0006= pd.date_range(start='2000-01-01', end='2006-12-31')
datetime_series_0006
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                '2000-01-09', '2000-01-10',
#                ...
#                '2006-12-22', '2006-12-23', '2006-12-24', '2006-12-25',
#                '2006-12-26', '2006-12-27', '2006-12-28', '2006-12-29',
#                '2006-12-30', '2006-12-31'],
#               dtype='datetime64[ns]', length=2557, freq='D')

# %%
df_VA_A = pd.concat([df_qmod_A1.loc[datetime_series_0006], df_qmod_A2.loc[datetime_series_0006], df_qmod_A3.loc[datetime_series_0006], df_qmod_A4.loc[datetime_series_0006], df_qmod_A5.loc[datetime_series_0006], df_nldas_f.loc[datetime_series_0006],  df_nldas_A4.loc[datetime_series_0006],  df_nldas_A3.loc[datetime_series_0006],  df_nldas_A2.loc[datetime_series_0006], df_nldas_A1.loc[datetime_series_0006], df_nldas_A5.loc[datetime_series_0006]])

# %%
df_VA_A.head()
# Out:
#              Step    Year  PET(mm/day)_Delineated_Average  \
# 2000-01-01  730.0  2000.0                        3.144678
# 2000-01-02  731.0  2000.0                        2.440319
# 2000-01-03  732.0  2000.0                        1.778834
# 2000-01-04  733.0  2000.0                        1.639974
# 2000-01-05  734.0  2000.0                        2.454456
#
#             ET(mm/day)_Delineated_Average  \
# 2000-01-01                       0.518602
# 2000-01-02                       0.393035
# 2000-01-03                       0.281402
# 2000-01-04                       0.255735
# 2000-01-05                       0.376485
#
#             Runoff_All(mm/day)_Delineated_Average  \
# 2000-01-01                               0.000204
# 2000-01-02                               0.000192
# 2000-01-03                               0.000183
# 2000-01-04                               0.000177
# 2000-01-05                               0.000169
#
# ...

# %%
df_VA_A.Run.unique()
# Out:
# array(['A1', 'A2', 'A3', 'A4', 'A5', 'NLDAS_293321', 'NLDAS_451289',
#        'NLDAS_421671', 'NLDAS_420929', 'NLDAS_659322', 'NLDAS_39377'],
#       dtype=object)

# %%
df_VA_A['Date'] = df_VA_A.index

# %%
df_VA_A.head()
# Out:
#              Step    Year  PET(mm/day)_Delineated_Average  \
# 2000-01-01  730.0  2000.0                        3.144678
# 2000-01-02  731.0  2000.0                        2.440319
# 2000-01-03  732.0  2000.0                        1.778834
# 2000-01-04  733.0  2000.0                        1.639974
# 2000-01-05  734.0  2000.0                        2.454456
#
#             ET(mm/day)_Delineated_Average  \
# 2000-01-01                       0.518602
# 2000-01-02                       0.393035
# 2000-01-03                       0.281402
# 2000-01-04                       0.255735
# 2000-01-05                       0.376485
#
#             Runoff_All(mm/day)_Delineated_Average  \
# 2000-01-01                               0.000204
# 2000-01-02                               0.000192
# 2000-01-03                               0.000183
# 2000-01-04                               0.000177
# 2000-01-05                               0.000169
#
# ...

# %%
df_VA_A = df_VA_A.reset_index()
df_VA_A
# Out:
#            index   Step    Year  PET(mm/day)_Delineated_Average  \
# 0     2000-01-01  730.0  2000.0                        3.144678
# 1     2000-01-02  731.0  2000.0                        2.440319
# 2     2000-01-03  732.0  2000.0                        1.778834
# 3     2000-01-04  733.0  2000.0                        1.639974
# 4     2000-01-05  734.0  2000.0                        2.454456
# ...          ...    ...     ...                             ...
# 28122 2006-12-27    NaN     NaN                             NaN
# 28123 2006-12-28    NaN     NaN                             NaN
# 28124 2006-12-29    NaN     NaN                             NaN
# 28125 2006-12-30    NaN     NaN                             NaN
# 28126 2006-12-31    NaN     NaN                             NaN
#
#        ET(mm/day)_Delineated_Average  Runoff_All(mm/day)_Delineated_Average  \
# 0                           0.518602                               0.000204
# ...

# %%
df_VA_A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28127 entries, 0 to 28126
# Data columns (total 10 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   index                                  28127 non-null  datetime64[ns]
#  1   Step                                   12785 non-null  float64
#  2   Year                                   12785 non-null  float64
#  3   PET(mm/day)_Delineated_Average         12785 non-null  float64
#  4   ET(mm/day)_Delineated_Average          15342 non-null  float64
#  5   Runoff_All(mm/day)_Delineated_Average  28127 non-null  float64
#  6   Rain(mm/day)_Delineated_Average        15342 non-null  float64
#  7   Run                                    28127 non-null  object
#  8   Total_Observed_Runoff(mm)              2557 non-null   float64
#  9   Date                                   28127 non-null  datetime64[ns]
# ...

# %%
sns.lineplot(df_VA_A, y='Runoff_All(mm/day)_Delineated_Average', x='Step',hue=df_VA_A.Run)
plt.ylim([-0.05,7])
# Out:
# (-0.05, 7.0)

# %%
df_VA_A_1 = df_VA_A.loc[((df_VA_A.Run == 'A1') | (df_VA_A.Run == 'NLDAS_293321'))]
df_VA_A_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5114 entries, 0 to 15341
# Data columns (total 10 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   index                                  5114 non-null   datetime64[ns]
#  1   Step                                   2557 non-null   float64
#  2   Year                                   2557 non-null   float64
#  3   PET(mm/day)_Delineated_Average         2557 non-null   float64
#  4   ET(mm/day)_Delineated_Average          5114 non-null   float64
#  5   Runoff_All(mm/day)_Delineated_Average  5114 non-null   float64
#  6   Rain(mm/day)_Delineated_Average        5114 non-null   float64
#  7   Run                                    5114 non-null   object
#  8   Total_Observed_Runoff(mm)              2557 non-null   float64
#  9   Date                                   5114 non-null   datetime64[ns]
# ...

# %%
df_VA_A_1.Run.unique()
# Out:
# array(['A1', 'NLDAS_293321'], dtype=object)

# %%
sns.scatterplot(df_VA_A_1, y=df_VA_A_1['Runoff_All(mm/day)_Delineated_Average'][:].loc[(df_VA_A_1.Run == 'A1')], x='Date')
# Out:
# <Axes: xlabel='Date', ylabel='Runoff_All(mm/day)_Delineated_Average'>

# %%
sns.scatterplot(df_VA_A_1, y=df_VA_A_1['Runoff_All(mm/day)_Delineated_Average'][:].loc[(df_VA_A_1.Run == 'NLDAS_293321')], x='Date')
# Out:
# <Axes: xlabel='Date', ylabel='Runoff_All(mm/day)_Delineated_Average'>

# %%
df_VA_A_1['Runoff_All(mm/day)_Delineated_Average_2'] = df_VA_A_1['Runoff_All(mm/day)_Delineated_Average'][:]
# Out:
# C:\Users\KVENABLE\AppData\Local\Temp\ipykernel_63316\2356449475.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_VA_A_1['Runoff_All(mm/day)_Delineated_Average_2'] = df_VA_A_1['Runoff_All(mm/day)_Delineated_Average'][:]

# %%
df_VA_A_1.head()
# Out:
#        index   Step    Year  PET(mm/day)_Delineated_Average  \
# 0 2000-01-01  730.0  2000.0                        3.144678
# 1 2000-01-02  731.0  2000.0                        2.440319
# 2 2000-01-03  732.0  2000.0                        1.778834
# 3 2000-01-04  733.0  2000.0                        1.639974
# 4 2000-01-05  734.0  2000.0                        2.454456
#
#    ET(mm/day)_Delineated_Average  Runoff_All(mm/day)_Delineated_Average  \
# 0                       0.518602                               0.000204
# 1                       0.393035                               0.000192
# 2                       0.281402                               0.000183
# 3                       0.255735                               0.000177
# 4                       0.376485                               0.000169
#
#    Rain(mm/day)_Delineated_Average Run  Total_Observed_Runoff(mm)       Date  \
# 0                              0.0  A1                        NaN 2000-01-01
# ...

# %%
df_qmod_A1.keys()
# Out:
# Index(['Step', 'Year', 'PET(mm/day)_Delineated_Average',
#        'ET(mm/day)_Delineated_Average',
#        'Runoff_All(mm/day)_Delineated_Average',
#        'Rain(mm/day)_Delineated_Average', 'Run'],
#       dtype='object')

# %%
sns.regplot(x=df_nldas_f['Runoff_All(mm/day)_Delineated_Average'][datetime_series_0006], y=df_nldas_A5['Runoff_All(mm/day)_Delineated_Average'][datetime_series_0006])
#NLDAS for Brush Creek outlet comparisson with NLDAS 39377 which displays a 1:1 correlation
# Out:
# <Axes: xlabel='Runoff_All(mm/day)_Delineated_Average', ylabel='Runoff_All(mm/day)_Delineated_Average'>

# %%
sns.lineplot(x=df_nldas_f['Runoff_All(mm/day)_Delineated_Average'][datetime_series_0006], y=df_nldas_A5['Runoff_All(mm/day)_Delineated_Average'][datetime_series_0006])
# Out:
# <Axes: xlabel='Runoff_All(mm/day)_Delineated_Average', ylabel='Runoff_All(mm/day)_Delineated_Average'>

# %%
stats.pearsonr(x=df_nldas_f['Runoff_All(mm/day)_Delineated_Average'][datetime_series_0006], y=df_nldas_A5['Runoff_All(mm/day)_Delineated_Average'][datetime_series_0006])
# Out:
# PearsonRResult(statistic=0.999990563329948, pvalue=0.0)

# %%
stats.describe(df_nldas_f['Runoff_All(mm/day)_Delineated_Average'][datetime_series_0006])
# Out:
# DescribeResult(nobs=2557, minmax=(0.0, 37.04), mean=0.17144035979663666, variance=0.9701249335504185, skewness=23.905625826708143, kurtosis=801.8523990099134)

# %%
stats.describe(df_nldas_A5['Runoff_All(mm/day)_Delineated_Average'][datetime_series_0006])
# Out:
# DescribeResult(nobs=2557, minmax=(0.0, 37.03), mean=0.17010950332420807, variance=0.9700017876913418, skewness=23.895917957042737, kurtosis=801.321760880047)

# %%
sns.color_palette("colorblind")
# Out:
# [(0.00392156862745098, 0.45098039215686275, 0.6980392156862745),
#  (0.8705882352941177, 0.5607843137254902, 0.0196078431372549),
#  (0.00784313725490196, 0.6196078431372549, 0.45098039215686275),
#  (0.8352941176470589, 0.3686274509803922, 0.0),
#  (0.8, 0.47058823529411764, 0.7372549019607844),
#  (0.792156862745098, 0.5686274509803921, 0.3803921568627451),
#  (0.984313725490196, 0.6862745098039216, 0.8941176470588236),
#  (0.5803921568627451, 0.5803921568627451, 0.5803921568627451),
#  (0.9254901960784314, 0.8823529411764706, 0.2),
#  (0.33725490196078434, 0.7058823529411765, 0.9137254901960784)]

# %%
sns.set_context('notebook', font_scale=1.5)
sns.set_palette('colorblind')
f = plt.figure(figsize=(16, 10))
gs = f.add_gridspec(2, 2)
#catplot(df_VA_A2_f, "point", df_VA_A2_f.index.month, "Runoff_All(mm/day)_Delineated_Average",'Run')
with sns.axes_style("white"):
    ax = f.add_subplot(gs[0, 0])
    #sns.set.color_palette("colorblind")
    sns.regplot(x=df_qmod_A5['Runoff_All(mm/day)_Delineated_Average'][datetime_series_0006], y=df_nldas_f['Runoff_All(mm/day)_Delineated_Average'][datetime_series_0006])
    ax.set_xlabel("Outlet 293321 VELMA RDA (mm/day)")
    ax.set_ylabel("NLDAS RDA (mm/day)")
    props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
    # place a text box in upper left in axes coords
    ax.text(4.05, 34.05, 'NSE = 0.620',
        horizontalalignment='center',
        verticalalignment='center',
        bbox=props)#,
with sns.axes_style("white"):
    ax = f.add_subplot(gs[0, 1])
    sns.regplot(x=df_qmod_A1['Runoff_All(mm/day)_Delineated_Average'][datetime_series_0006], y=df_nldas_A5['Runoff_All(mm/day)_Delineated_Average'][datetime_series_0006])
    ax.set_xlabel("Outlet 659322 VELMA RDA (mm/day)")
    ax.set_ylabel("NLDAS RDA (mm/day)")
    props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
    # place a text box in upper left in axes coords
    plt.text(4.05, 34.05, 'NSE = 0.609',
        horizontalalignment='center',
        verticalalignment='center',
        bbox=props)
with sns.axes_style("white"):
    ax = f.add_subplot(gs[1, 0])
    sns.regplot(x=df_qmod_A3['Runoff_All(mm/day)_Delineated_Average'][datetime_series_0006], y=df_nldas_A5['Runoff_All(mm/day)_Delineated_Average'][datetime_series_0006])
    ax.set_xlabel("Outlet 421671 VELMA RDA (mm/day)")
    ax.set_ylabel("NLDAS RDA (mm/day)")
    props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
    # place a text box in upper left in axes coords
    plt.text(3.05, 46.05, 'NSE = 0.600',
        horizontalalignment='center',
        verticalalignment='center',
        bbox=props)
with sns.axes_style("white"):
    ax = f.add_subplot(gs[1, 1])
    sns.regplot(x=df_qmod_A4['Runoff_All(mm/day)_Delineated_Average'][datetime_series_0006], y=df_nldas_A5['Runoff_All(mm/day)_Delineated_Average'][datetime_series_0006])
    ax.set_xlabel("Outlet 451289 VELMA RDA (mm/day)")
    ax.set_ylabel("NLDAS RDA (mm/day)")
    # these are matplotlib.patch.Patch properties
    props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
    # place a text box in upper left in axes coords
    plt.text(3.15, 46.05, 'NSE = 0.600',
        horizontalalignment='center',
        verticalalignment='center',
        bbox=props)

#ax.add_legend()
f.tight_layout()
